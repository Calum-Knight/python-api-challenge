# %%
 # Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import random


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# Import API key
from api_keys import weather_api_key

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 641

# %%
url = f"https://api.openweathermap.org/data/2.5/weather?&appid={weather_api_key}&units=metric"

# %%
Country = []
City=[]
Temp = []
Feels_Like = []
Weather = []
Longitude=[]
Latitude=[]
Sunrise = []
Sunset=[]
Date=[]
Humidity=[]
Cloudiness=[]
WindSpeed=[]

counter = 0

print("Beginning Data Retrieval")  
print("-----------------------------")

for city in cities:
    query_url = url + "&q=" + city
    #get response
    response = requests.get(query_url).json()
    counter += 1
    try:
        Country.append(response["sys"]["country"])
        City.append(response["name"])
        Temp.append(response["main"]["temp_max"])
        Weather.append(response["weather"][0]["main"])
        Longitude.append(response["coord"]["lon"])
        Latitude.append(response["coord"]["lat"])
        Sunrise.append(response["sys"]["sunrise"])
        Sunset.append(response["sys"]["sunset"])
        Humidity.append(response["main"]["humidity"])
        Date.append(response["dt"])
        Cloudiness.append(response["clouds"]["all"])
        WindSpeed.append(response["wind"]["speed"])
        
        print(f"Processing Record {counter}: {city}")
        
    except:
        print(f"Processing Record {counter}: City Not Found ... Skipping...")
    

print("-----------------------")
print("End of Process")
print("-----------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1: arraial do cabo
# Processing Record 2: jamestown
# Processing Record 3: gazojak
# Processing Record 4: swarzedz
# Processing Record 5: rapid valley
# Processing Record 6: City Not Found ... Skipping...
# Processing Record 7: hobart
# Processing Record 8: City Not Found ... Skipping...
# Processing Record 9: hermanus
# Processing Record 10: City Not Found ... Skipping...
# Processing Record 11: City Not Found ... Skipping...
# Processing Record 12: serowe
# Processing Record 13: hobyo
# Processing Record 14: erdenet
# Processing Record 15: moissac
# Processing Record 16: mataura
# Processing Record 17: rikitea
# Processing Record 18: chumikan
# Processing Record 19: tucurui
# Processing Record 20: kodino
# Processing Record 21: hualmay
# Processing Record 22: richards bay
# Processing Record 23: City Not Found ... Skipping...
# Processing Record 24: punta arenas
# Processing Record 25: sola
# Processing Record 26: kawalu
# Processing Record 27: atuona
# Processing Record 28: City Not Found ... Skipping...
# Processing Record 29: tucumcari
# Processing Record 30: dikson
# Processing Record 31: puerto ayora
# Processing Record 32: namibe
# Processing Record 33: gimli
# Processing Record 34: mandleshwar
# Processing Record 35: City Not Found ... Skipping...
# Processing Record 36: katsuura
# Processing Record 37: cabo san lucas
# Processing Record 38: bethel
# Processing Record 39: vaini
# Processing Record 40: City Not Found ... Skipping...
# Processing Record 41: airai
# Processing Record 42: awbari
# Processing Record 43: alice town
# Processing Record 44: hasaki
# Processing Record 45: poya
# Processing Record 46: bluff
# Processing Record 47: upernavik
# Processing Record 48: balkanabat
# Processing Record 49: hambantota
# Processing Record 50: biak
# Processing Record 51: avarua
# Processing Record 52: okha
# Processing Record 53: bentong
# Processing Record 54: albany
# Processing Record 55: chuy
# Processing Record 56: sur
# Processing Record 57: mopti
# Processing Record 58: ponta do sol
# Processing Record 59: hubli
# Processing Record 60: miquelon
# Processing Record 61: nichinan
# Processing Record 62: nakamura
# Processing Record 63: son la
# Processing Record 64: te anau
# Processing Record 65: alamogordo
# Processing Record 66: busselton
# Processing Record 67: igarka
# Processing Record 68: ketchikan
# Processing Record 69: sioux lookout
# Processing Record 70: saint-augustin
# Processing Record 71: chokurdakh
# Processing Record 72: nouadhibou
# Processing Record 73: codrington
# Processing Record 74: east london
# Processing Record 75: port elizabeth
# Processing Record 76: yar-sale
# Processing Record 77: bengkulu
# Processing Record 78: saskylakh
# Processing Record 79: thompson
# Processing Record 80: ushuaia
# Processing Record 81: college
# Processing Record 82: new norfolk
# Processing Record 83: klaksvik
# Processing Record 84: guerrero negro
# Processing Record 85: bani
# Processing Record 86: napier
# Processing Record 87: esperance
# Processing Record 88: castro
# Processing Record 89: tessalit
# Processing Record 90: ilulissat
# Processing Record 91: saint-pierre
# Processing Record 92: mayo
# Processing Record 93: fort nelson
# Processing Record 94: webuye
# Processing Record 95: cayenne
# Processing Record 96: lata
# Processing Record 97: City Not Found ... Skipping...
# Processing Record 98: la ronge
# Processing Record 99: tiarei
# Processing Record 100: barrow
# Processing Record 101: qaanaaq
# Processing Record 102: City Not Found ... Skipping...
# Processing Record 103: lorengau
# Processing Record 104: axim
# Processing Record 105: lipin bor
# Processing Record 106: City Not Found ... Skipping...
# Processing Record 107: fidenza
# Processing Record 108: yellowknife
# Processing Record 109: camacha
# Processing Record 110: la mira
# Processing Record 111: butaritari
# Processing Record 112: colon
# Processing Record 113: geraldton
# Processing Record 114: saravan
# Processing Record 115: georgetown
# Processing Record 116: caravelas
# Processing Record 117: luderitz
# Processing Record 118: kudat
# Processing Record 119: leshukonskoye
# Processing Record 120: cape town
# Processing Record 121: nyagan
# Processing Record 122: ostrovnoy
# Processing Record 123: cidreira
# Processing Record 124: carballo
# Processing Record 125: port alfred
# Processing Record 126: City Not Found ... Skipping...
# Processing Record 127: sao joao da barra
# Processing Record 128: san andres
# Processing Record 129: pevek
# Processing Record 130: innisfail
# Processing Record 131: ndele
# Processing Record 132: coihaique
# Processing Record 133: contamana
# Processing Record 134: seymchan
# Processing Record 135: City Not Found ... Skipping...
# Processing Record 136: port lincoln
# Processing Record 137: zhigansk
# Processing Record 138: durban
# Processing Record 139: kruisfontein
# Processing Record 140: City Not Found ... Skipping...
# Processing Record 141: jagatsinghapur
# Processing Record 142: saint george
# Processing Record 143: tuktoyaktuk
# Processing Record 144: vyartsilya
# Processing Record 145: souillac
# Processing Record 146: mayya
# Processing Record 147: ambilobe
# Processing Record 148: tuatapere
# Processing Record 149: labuhan
# Processing Record 150: kudahuvadhoo
# Processing Record 151: dingle
# Processing Record 152: City Not Found ... Skipping...
# Processing Record 153: batemans bay
# Processing Record 154: faanui
# Processing Record 155: linxia
# Processing Record 156: itatskiy
# Processing Record 157: mutsu
# Processing Record 158: huarmey
# Processing Record 159: puerto escondido
# Processing Record 160: hefei
# Processing Record 161: sarakhs
# Processing Record 162: ulladulla
# Processing Record 163: City Not Found ... Skipping...
# Processing Record 164: aswan
# Processing Record 165: vurgun
# Processing Record 166: banda aceh
# Processing Record 167: tarnogskiy gorodok
# Processing Record 168: severo-kurilsk
# Processing Record 169: saiha
# Processing Record 170: hithadhoo
# Processing Record 171: neryungri
# Processing Record 172: prince rupert
# Processing Record 173: City Not Found ... Skipping...
# Processing Record 174: alofi
# Processing Record 175: shenzhen
# Processing Record 176: kahramanmaras
# Processing Record 177: khatanga
# Processing Record 178: bagenalstown
# Processing Record 179: mar del plata
# Processing Record 180: bom jesus
# Processing Record 181: moron
# Processing Record 182: mahebourg
# Processing Record 183: nanortalik
# Processing Record 184: mount isa
# Processing Record 185: kahului
# Processing Record 186: pangnirtung
# Processing Record 187: hamilton
# Processing Record 188: los llanos de aridane
# Processing Record 189: limoeiro do ajuru
# Processing Record 190: pekalongan
# Processing Record 191: kropotkin
# Processing Record 192: provideniya
# Processing Record 193: saint-francois
# Processing Record 194: kapaa
# Processing Record 195: City Not Found ... Skipping...
# Processing Record 196: falun
# Processing Record 197: cermik
# Processing Record 198: City Not Found ... Skipping...
# Processing Record 199: ribeira grande
# Processing Record 200: semirom
# Processing Record 201: gardiner
# Processing Record 202: marzuq
# Processing Record 203: dunedin
# Processing Record 204: tefe
# Processing Record 205: chardara
# Processing Record 206: City Not Found ... Skipping...
# Processing Record 207: knysna
# Processing Record 208: waipawa
# Processing Record 209: flinders
# Processing Record 210: City Not Found ... Skipping...
# Processing Record 211: bredasdorp
# Processing Record 212: samarai
# Processing Record 213: takestan
# Processing Record 214: nauta
# Processing Record 215: biasca
# Processing Record 216: kuopio
# Processing Record 217: mantua
# Processing Record 218: City Not Found ... Skipping...
# Processing Record 219: yichun
# Processing Record 220: hilo
# Processing Record 221: hami
# Processing Record 222: la grande
# Processing Record 223: dakar
# Processing Record 224: margate
# Processing Record 225: conceicao do araguaia
# Processing Record 226: manati
# Processing Record 227: lompoc
# Processing Record 228: sao filipe
# Processing Record 229: dandong
# Processing Record 230: messina
# Processing Record 231: krasnorechenskiy
# Processing Record 232: avera
# Processing Record 233: kijini
# Processing Record 234: bardiyah
# Processing Record 235: sri aman
# Processing Record 236: City Not Found ... Skipping...
# Processing Record 237: bilma
# Processing Record 238: sorland
# Processing Record 239: bursa
# Processing Record 240: iqaluit
# Processing Record 241: yakeshi
# Processing Record 242: kyra
# Processing Record 243: clermont
# Processing Record 244: beisfjord
# Processing Record 245: narsaq
# Processing Record 246: sibu
# Processing Record 247: taywarah
# Processing Record 248: miri
# Processing Record 249: caruray
# Processing Record 250: saint-junien
# Processing Record 251: paramaribo
# Processing Record 252: olafsvik
# Processing Record 253: soe
# Processing Record 254: rocha
# Processing Record 255: vila velha
# Processing Record 256: bafq
# Processing Record 257: the valley
# Processing Record 258: bassila
# Processing Record 259: spasskoye
# Processing Record 260: lavrentiya
# Processing Record 261: oranjemund
# Processing Record 262: City Not Found ... Skipping...
# Processing Record 263: nikolskoye
# Processing Record 264: broken hill
# Processing Record 265: khandyga
# Processing Record 266: torbay
# Processing Record 267: shache
# Processing Record 268: mansehra
# Processing Record 269: roma
# Processing Record 270: ancud
# Processing Record 271: mujiayingzi
# Processing Record 272: broome
# Processing Record 273: tiksi
# Processing Record 274: sturgis
# Processing Record 275: lakes entrance
# Processing Record 276: kodiak
# Processing Record 277: maniitsoq
# Processing Record 278: kabo
# Processing Record 279: hofn
# Processing Record 280: kaoma
# Processing Record 281: tasiilaq
# Processing Record 282: fairbanks
# Processing Record 283: aitape
# Processing Record 284: harstad
# Processing Record 285: komsomolskiy
# Processing Record 286: cherskiy
# Processing Record 287: leningradskiy
# Processing Record 288: carnarvon
# Processing Record 289: gomel
# Processing Record 290: kavieng
# Processing Record 291: nome
# Processing Record 292: kovdor
# Processing Record 293: parainen
# Processing Record 294: jackson
# Processing Record 295: punta alta
# Processing Record 296: lebu
# Processing Record 297: grand gaube
# Processing Record 298: krasnyy chikoy
# Processing Record 299: kanker
# Processing Record 300: City Not Found ... Skipping...
# Processing Record 301: makarov
# Processing Record 302: City Not Found ... Skipping...
# Processing Record 303: sitka
# Processing Record 304: salinopolis
# Processing Record 305: la rioja
# Processing Record 306: saint-joseph
# Processing Record 307: City Not Found ... Skipping...
# Processing Record 308: kasongo-lunda
# Processing Record 309: shaoguan
# Processing Record 310: bolobo
# Processing Record 311: City Not Found ... Skipping...
# Processing Record 312: City Not Found ... Skipping...
# Processing Record 313: lagoa
# Processing Record 314: itigi
# Processing Record 315: kedrovyy
# Processing Record 316: svay rieng
# Processing Record 317: necochea
# Processing Record 318: City Not Found ... Skipping...
# Processing Record 319: beidao
# Processing Record 320: port blair
# Processing Record 321: takaka
# Processing Record 322: bichura
# Processing Record 323: salou
# Processing Record 324: nanchang
# Processing Record 325: itoman
# Processing Record 326: bafoulabe
# Processing Record 327: shimoda
# Processing Record 328: helong
# Processing Record 329: kinablangan
# Processing Record 330: vila franca do campo
# Processing Record 331: ust-omchug
# Processing Record 332: badulla
# Processing Record 333: City Not Found ... Skipping...
# Processing Record 334: portland
# Processing Record 335: basco
# Processing Record 336: peterhead
# Processing Record 337: roura
# Processing Record 338: aksarka
# Processing Record 339: harqalah
# Processing Record 340: sakaraha
# Processing Record 341: tazovskiy
# Processing Record 342: City Not Found ... Skipping...
# Processing Record 343: poum
# Processing Record 344: taoudenni
# Processing Record 345: vardo
# Processing Record 346: City Not Found ... Skipping...
# Processing Record 347: City Not Found ... Skipping...
# Processing Record 348: bubaque
# Processing Record 349: buchanan
# Processing Record 350: saint-philippe
# Processing Record 351: poronaysk
# Processing Record 352: City Not Found ... Skipping...
# Processing Record 353: saint anthony
# Processing Record 354: City Not Found ... Skipping...
# Processing Record 355: victoria
# Processing Record 356: City Not Found ... Skipping...
# Processing Record 357: sayyan
# Processing Record 358: aklavik
# Processing Record 359: narrabri
# Processing Record 360: saint-leu
# Processing Record 361: brae
# Processing Record 362: ouegoa
# Processing Record 363: verkhovye
# Processing Record 364: vao
# Processing Record 365: vizinga
# Processing Record 366: sobolevo
# Processing Record 367: envira
# Processing Record 368: belaya gora
# Processing Record 369: balabac
# Processing Record 370: beringovskiy
# Processing Record 371: zabaykalsk
# Processing Record 372: vung tau
# Processing Record 373: City Not Found ... Skipping...
# Processing Record 374: fairview
# Processing Record 375: marsabit
# Processing Record 376: isangel
# Processing Record 377: arawa
# Processing Record 378: longyearbyen
# Processing Record 379: constitucion
# Processing Record 380: kutum
# Processing Record 381: nemuro
# Processing Record 382: City Not Found ... Skipping...
# Processing Record 383: rincon
# Processing Record 384: mahabad
# Processing Record 385: port-gentil
# Processing Record 386: sao jose da coroa grande
# Processing Record 387: piracuruca
# Processing Record 388: micheweni
# Processing Record 389: phalombe
# Processing Record 390: drayton valley
# Processing Record 391: hatillo
# Processing Record 392: nantucket
# Processing Record 393: jiutai
# Processing Record 394: sinnamary
# Processing Record 395: datong
# Processing Record 396: grindavik
# Processing Record 397: evensk
# Processing Record 398: vila
# Processing Record 399: rabo de peixe
# Processing Record 400: fortuna
# Processing Record 401: srednekolymsk
# Processing Record 402: zharkovskiy
# Processing Record 403: ust-ilimsk
# Processing Record 404: shihezi
# Processing Record 405: marystown
# Processing Record 406: baishishan
# Processing Record 407: japura
# Processing Record 408: piacabucu
# Processing Record 409: minot
# Processing Record 410: balboa
# Processing Record 411: dicabisagan
# Processing Record 412: sapernoye
# Processing Record 413: City Not Found ... Skipping...
# Processing Record 414: bonavista
# Processing Record 415: mayumba
# Processing Record 416: bitkine
# Processing Record 417: tahta
# Processing Record 418: rawson
# Processing Record 419: bambous virieux
# Processing Record 420: ayagoz
# Processing Record 421: bathsheba
# Processing Record 422: City Not Found ... Skipping...
# Processing Record 423: stromness
# Processing Record 424: telhara
# Processing Record 425: hornepayne
# Processing Record 426: kaitangata
# Processing Record 427: City Not Found ... Skipping...
# Processing Record 428: isiro
# Processing Record 429: City Not Found ... Skipping...
# Processing Record 430: furth im wald
# Processing Record 431: aquiraz
# Processing Record 432: alice springs
# Processing Record 433: khasan
# Processing Record 434: alta floresta
# Processing Record 435: shelburne
# Processing Record 436: mount gambier
# Processing Record 437: kuala pilah
# Processing Record 438: City Not Found ... Skipping...
# Processing Record 439: kakonko
# Processing Record 440: pochutla
# Processing Record 441: khunti
# Processing Record 442: City Not Found ... Skipping...
# Processing Record 443: uvira
# Processing Record 444: artesia
# Processing Record 445: pisco
# Processing Record 446: hyderabad
# Processing Record 447: talcahuano
# Processing Record 448: itacare
# Processing Record 449: clyde river
# Processing Record 450: sfantu gheorghe
# Processing Record 451: san jeronimo
# Processing Record 452: kyshtovka
# Processing Record 453: lumajang
# Processing Record 454: porto novo
# Processing Record 455: progreso
# Processing Record 456: tandil
# Processing Record 457: catamarca
# Processing Record 458: bataipora
# Processing Record 459: mansa
# Processing Record 460: henties bay
# Processing Record 461: nhulunbuy
# Processing Record 462: kongolo
# Processing Record 463: huai thalaeng
# Processing Record 464: killybegs
# Processing Record 465: mbaiki
# Processing Record 466: ustyuzhna
# Processing Record 467: russell
# Processing Record 468: pabbi
# Processing Record 469: touros
# Processing Record 470: tvoroyri
# Processing Record 471: kyren
# Processing Record 472: deputatskiy
# Processing Record 473: petropavlovsk-kamchatskiy
# Processing Record 474: acarau
# Processing Record 475: aykhal
# Processing Record 476: City Not Found ... Skipping...
# Processing Record 477: price
# Processing Record 478: kazachinskoye
# Processing Record 479: City Not Found ... Skipping...
# Processing Record 480: ihosy
# Processing Record 481: City Not Found ... Skipping...
# Processing Record 482: yingcheng
# Processing Record 483: sakaiminato
# Processing Record 484: makakilo city
# Processing Record 485: taungdwingyi
# Processing Record 486: bonfim
# Processing Record 487: soma
# Processing Record 488: harper
# Processing Record 489: santa cruz
# Processing Record 490: chateaubelair
# Processing Record 491: magsalangi
# Processing Record 492: guanica
# Processing Record 493: breves
# Processing Record 494: City Not Found ... Skipping...
# Processing Record 495: buala
# Processing Record 496: pacific grove
# Processing Record 497: burnie
# Processing Record 498: City Not Found ... Skipping...
# Processing Record 499: hauterive
# Processing Record 500: taltal
# Processing Record 501: solnechnyy
# Processing Record 502: nuuk
# Processing Record 503: tshikapa
# Processing Record 504: limanowa
# Processing Record 505: tobol
# Processing Record 506: mathathane
# Processing Record 507: saldanha
# Processing Record 508: alyangula
# Processing Record 509: pemangkat
# Processing Record 510: beloha
# Processing Record 511: mega
# Processing Record 512: camargo
# Processing Record 513: chodavaram
# Processing Record 514: norman wells
# Processing Record 515: praia
# Processing Record 516: charters towers
# Processing Record 517: rajapur
# Processing Record 518: City Not Found ... Skipping...
# Processing Record 519: kurskaya
# Processing Record 520: portlethen
# Processing Record 521: gamba
# Processing Record 522: majene
# Processing Record 523: itaberai
# Processing Record 524: dubbo
# Processing Record 525: yartsevo
# Processing Record 526: ust-tsilma
# Processing Record 527: svetlaya
# Processing Record 528: banagher
# Processing Record 529: qaqortoq
# Processing Record 530: akureyri
# Processing Record 531: fukue
# Processing Record 532: preobrazheniye
# Processing Record 533: pierre
# Processing Record 534: tubuala
# Processing Record 535: paamiut
# Processing Record 536: City Not Found ... Skipping...
# Processing Record 537: palu
# Processing Record 538: bragadiru
# Processing Record 539: masuguru
# Processing Record 540: christchurch
# Processing Record 541: saurimo
# Processing Record 542: praia da vitoria
# Processing Record 543: asosa
# Processing Record 544: middelburg
# Processing Record 545: ofunato
# Processing Record 546: najran
# Processing Record 547: yenagoa
# Processing Record 548: tingi
# Processing Record 549: san quintin
# Processing Record 550: baisha
# Processing Record 551: raudeberg
# Processing Record 552: ixtapa
# Processing Record 553: berlevag
# Processing Record 554: talkha
# Processing Record 555: bay roberts
# Processing Record 556: romny
# Processing Record 557: tarko-sale
# Processing Record 558: trinidad
# Processing Record 559: kununurra
# Processing Record 560: damaturu
# Processing Record 561: khromtau
# Processing Record 562: auki
# Processing Record 563: port augusta
# Processing Record 564: mitsamiouli
# Processing Record 565: odessa
# Processing Record 566: mosquera
# Processing Record 567: santa isabel do rio negro
# Processing Record 568: tongling
# Processing Record 569: jiayuguan
# Processing Record 570: tiznit
# Processing Record 571: atbasar
# Processing Record 572: buin
# Processing Record 573: ishigaki
# Processing Record 574: marabba
# Processing Record 575: imbituba
# Processing Record 576: nicoya
# Processing Record 577: port keats
# Processing Record 578: ankazoabo
# Processing Record 579: moree
# Processing Record 580: swan hill
# Processing Record 581: outlook
# Processing Record 582: cairns
# Processing Record 583: le vauclin
# Processing Record 584: inverell
# Processing Record 585: kirakira
# Processing Record 586: City Not Found ... Skipping...
# Processing Record 587: puerto colombia
# Processing Record 588: gizo
# Processing Record 589: hohhot
# Processing Record 590: truckee
# Processing Record 591: abu samrah
# Processing Record 592: corralillo
# Processing Record 593: oktyabrskiy
# Processing Record 594: erenhot
# Processing Record 595: chapaevsk
# Processing Record 596: City Not Found ... Skipping...
# Processing Record 597: tomatlan
# Processing Record 598: amapa
# Processing Record 599: besikduzu
# Processing Record 600: cockburn town
# Processing Record 601: angoche
# Processing Record 602: meulaboh
# Processing Record 603: lisala
# Processing Record 604: palmer
# Processing Record 605: ahipara
# Processing Record 606: timizart
# Processing Record 607: khanpur
# Processing Record 608: comodoro rivadavia
# Processing Record 609: pogranichnyy
# Processing Record 610: chern
# Processing Record 611: brandys nad labem-stara boleslav
# Processing Record 612: cartagena
# Processing Record 613: mayna
# Processing Record 614: hit
# Processing Record 615: abu dhabi
# Processing Record 616: tarakan
# Processing Record 617: magnitogorsk
# Processing Record 618: City Not Found ... Skipping...
# Processing Record 619: phetchaburi
# Processing Record 620: nara
# Processing Record 621: saint-louis
# Processing Record 622: waitati
# Processing Record 623: fare
# Processing Record 624: khor
# Processing Record 625: gazli
# Processing Record 626: City Not Found ... Skipping...
# Processing Record 627: carandai
# Processing Record 628: xingyi
# Processing Record 629: jalu
# Processing Record 630: havelock
# Processing Record 631: kidal
# Processing Record 632: maroantsetra
# Processing Record 633: winneba
# Processing Record 634: capao bonito
# Processing Record 635: kuragino
# Processing Record 636: tigil
# Processing Record 637: bandarbeyla
# Processing Record 638: idlib
# Processing Record 639: nybro
# Processing Record 640: itaberaba
# Processing Record 641: taseyevo
# -----------------------
# End of Process
# -----------------------

# %%
weather_df = pd.DataFrame({"City": City,
                          "Longitude":Longitude,
                          "Latitude":Latitude,                          
                          "Max Temperature (°C)":Temp,
                           "Humidity": Humidity,
                           "Cloudiness": Cloudiness,
                           "Wind Speed" : WindSpeed,
                           "Country":Country,
                           "Weather":Weather,
                           "Date": Date,
                          "Sunrise": Sunrise,
                          "Sunset": Sunset})
weather_df
# Out:
#                 City  Longitude  Latitude  Max Temperature (°C)  Humidity  \
# 0    Arraial do Cabo   -42.0278  -22.9661                 26.98        69
# 1          Jamestown   -79.2353   42.0970                 25.85        46
# 2            Gazojak    61.4036   41.1875                 29.26        15
# 3           Swarzędz    17.0850   52.4129                 21.61        67
# 4       Rapid Valley  -103.1463   44.0625                 37.24        56
# ..               ...        ...       ...                   ...       ...
# 580      Bandarbeyla    50.8122    9.4942                 26.73        62
# 581            Idlib    36.6339   35.9306                 25.56        53
# 582            Nybro    15.9071   56.7446                 19.58        38
# 583        Itaberaba   -40.3069  -12.5275                 24.34        64
# 584         Taseyevo    94.8978   57.2169                 16.68        68
#
#      Cloudiness  Wind Speed Country Weather        Date     Sunrise  \
# 0            20        5.14      BR  Clouds  1657386959  1657358958
# 1             0        4.63      US   Clear  1657386959  1657360174
# 2             0        5.08      TM   Clear  1657386959  1657326583
# 3            20        5.66      PL  Clouds  1657386960  1657334419
# 4             0        8.23      US   Clear  1657386960  1657365507
# ..          ...         ...     ...     ...         ...         ...
# 580          64       13.07      SO  Clouds  1657387071  1657333336
# 581           0        6.98      SY   Clear  1657386945  1657333461
# 582          38        4.86      SE  Clouds  1657386775  1657333040
# 583          95        3.19      BR  Clouds  1657386888  1657357411
# 584          98        0.60      RU  Clouds  1657387071  1657400328
#
#          Sunset
# 0    1657397816
# 1    1657414462
# 2    1657380539
# 3    1657393978
# 4    1657420607
# ..          ...
# 580  1657378870
# 581  1657385552
# 582  1657395923
# 583  1657398538
# 584  1657463532
#
# [585 rows x 12 columns]

# %%
weather_df.describe()
# Out:
#         Longitude    Latitude  Max Temperature (°C)    Humidity  Cloudiness  \
# count  585.000000  585.000000            585.000000  585.000000  585.000000
# mean    26.134236   19.644722             21.199624   69.666667   56.500855
# std     88.946444   33.321978              8.335703   22.022638   38.696931
# min   -175.200000  -54.800000             -1.190000    5.000000    0.000000
# 25%    -52.000000   -7.381700             15.620000   58.000000   18.000000
# 50%     30.475800   22.545500             22.350000   76.000000   64.000000
# 75%    108.208200   47.599900             27.030000   87.000000   98.000000
# max    179.316700   78.218600             46.070000  100.000000  100.000000
#
#        Wind Speed          Date       Sunrise        Sunset
# count  585.000000  5.850000e+02  5.850000e+02  5.850000e+02
# mean     3.793162  1.657387e+09  1.575204e+09  1.575251e+09
# std      2.386516  6.879532e+01  3.600559e+08  3.600666e+08
# min      0.000000  1.657386e+09  0.000000e+00  0.000000e+00
# 25%      2.000000  1.657387e+09  1.657337e+09  1.657387e+09
# 50%      3.240000  1.657387e+09  1.657359e+09  1.657404e+09
# 75%      5.140000  1.657387e+09  1.657394e+09  1.657437e+09
# max     13.210000  1.657387e+09  1.657477e+09  1.657534e+09

# %%
weather_df["Humidity"].max()
# Out:
# 100

# %% [markdown]
# Highest Humidity value is 100 and therefore no city has a Humidity over 100%

# %%
plt.scatter(weather_df["Latitude"],weather_df["Max Temperature (°C)"])
plt.xlabel("Lattitude")
plt.ylabel("Max Temp (°C)")
plt.title("Max Temp vs Latitude (09.07.2022)")
# Out:
# Text(0.5, 1.0, 'Max Temp vs Latitude (09.07.2022)')

# %% [markdown]
# This scatter plot shows the Max tempuratures for the selected cities on 9th July 2022. It clearly indicates that the highest temperatures were just north of the equator, at roughtly latitude 15°. I would assume that this would be due tile of the Earth's axis which creates the summer in the northern hemisphere and winter in the south during July.

# %%
plt.scatter(weather_df["Latitude"],weather_df["Humidity"])
plt.xlabel("Lattitude")
plt.ylabel("Humidity (%)")
plt.title("Humidity vs Latitude (09.07.2022)")
# Out:
# Text(0.5, 1.0, 'Humidity vs Latitude (09.07.2022)')

# %% [markdown]
# This scatter plot shows humidity vs latitude. I would conclude that there is not a strong relationship here on first glance. However, it appears to be more common that the humidity drops nearer the equator.

# %%
plt.scatter(weather_df["Latitude"],weather_df["Cloudiness"])
plt.xlabel("Lattitude")
plt.ylabel("Cloudiness")
plt.title("Cloudiness vs Latitude (09.07.2022)")
# Out:
# Text(0, 0.5, 'Cloudiness')

# %% [markdown]
# This scatter plot shows that there is little correlation between the "cloudiness" and the latitude.

# %%
plt.scatter(weather_df["Latitude"],weather_df["Wind Speed"])
plt.xlabel("Lattitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Wind Speed vs Latitude (09.07.2022)")
plt.show()

# %% [markdown]
# This scatter plot shows very little correlation for wind speed vs latitude. However, the extreme high winds seem to have occured between 20° and -20°.

# %%
north_df = weather_df[weather_df["Latitude"]>0]
south_df = weather_df[weather_df["Latitude"]<0]

# %%
plt.figure().set_figheight(10)
plt.figure().set_figwidth(15)
plt.subplot(1,2,1)

x_values = north_df["Latitude"]
y_values = north_df["Max Temperature (°C)"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_values,y_values,c="g")
plt.plot(x_values,regress_values,c="red", linewidth = 2.5)
plt.xlabel("Lattitude")
plt.ylabel("Max Temp (°C)")
plt.title("Northern Hemisphere - Max Temp vs Latitude (09.07.2022)")

plt.figure().set_figheight(10)
plt.figure().set_figwidth(15)

plt.subplot(1,2,2)


x_values = south_df["Latitude"]
y_values = south_df["Max Temperature (°C)"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values,c="g")
plt.plot(x_values,regress_values,c="red", linewidth = 2.5)
plt.xlabel("Lattitude")
plt.ylabel("Max Temp (°C)")
plt.title("Southern Hemisphere - Max Temp vs Latitude (09.07.2022)")

plt.show()

# %% [markdown]
# These graphes both indicate a strong relationship between max temperature and proxiity to the equator. However, the equator does not appear to be the centre point. The centre point seems to be slightly north of the equator, which is expected due to the time of year and the Earth's tilt.

# %%
plt.figure().set_figheight(10)
plt.figure().set_figwidth(15)
plt.subplot(1,2,1)

x_values = north_df["Latitude"]
y_values = north_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_values,y_values,c="g")
plt.plot(x_values,regress_values,c="red", linewidth = 2.5)
plt.xlabel("Lattitude")
plt.ylabel("Humidity (%)")
plt.title("Northern Hemisphere - Max Temp vs Latitude (09.07.2022)")

plt.figure().set_figheight(10)
plt.figure().set_figwidth(15)

plt.subplot(1,2,2)


x_values = south_df["Latitude"]
y_values = south_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values,c="g")
plt.plot(x_values,regress_values,c="red", linewidth = 2.5)
plt.xlabel("Lattitude")
plt.ylabel("Humidity (%)")
plt.title("Southern Hemisphere - Max Temp vs Latitude (09.07.2022)")

plt.show()

# %% [markdown]
# Looks to be a slight correlation with lower humidity nearer the equator. There also appears to be significantly more data for the north than the south. This could be down to sample size, but may also be because of the larger landmasses in the north?

# %%
plt.figure().set_figheight(10)
plt.figure().set_figwidth(15)
plt.subplot(1,2,1)

x_values = north_df["Latitude"]
y_values = north_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_values,y_values,c="g")
plt.plot(x_values,regress_values,c="red", linewidth = 2.5)
plt.xlabel("Lattitude")
plt.ylabel("Cloudiness")
plt.title("Northern Hemisphere - Max Temp vs Latitude (09.07.2022)")

plt.figure().set_figheight(10)
plt.figure().set_figwidth(15)

plt.subplot(1,2,2)


x_values = south_df["Latitude"]
y_values = south_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values,c="g")
plt.plot(x_values,regress_values,c="red", linewidth = 2.5)
plt.xlabel("Lattitude")
plt.ylabel("Cloudiness")
plt.title("Southern Hemisphere - Max Temp vs Latitude (09.07.2022)")

plt.show()

# %%
plt.figure().set_figheight(10)
plt.figure().set_figwidth(15)
plt.subplot(1,2,1)

x_values = north_df["Latitude"]
y_values = north_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_values,y_values,c="g")
plt.plot(x_values,regress_values,c="red", linewidth = 2.5)
plt.xlabel("Lattitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Northern Hemisphere - Max Temp vs Latitude (09.07.2022)")

plt.figure().set_figheight(10)
plt.figure().set_figwidth(15)

plt.subplot(1,2,2)


x_values = south_df["Latitude"]
y_values = south_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values,c="g")
plt.plot(x_values,regress_values,c="red", linewidth = 2.5)
plt.xlabel("Lattitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Southern Hemisphere - Max Temp vs Latitude (09.07.2022)")

plt.show()
